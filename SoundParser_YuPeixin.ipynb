# %%
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#pathBase = 'E://Chuan//Documents//GitHub//AusculPi//Data//VSD//'
#pathBase = 'I://Chuan//Documents//GitHub//AusculPi//Data//VSD//'
#pathBase = 'C://Users//Chuan//OneDrive//Dowrun//Text//Manuscripts//Sound//TAVR_post//'

# %%
pathBase = 'C://Users//triti//OneDrive//Dowrun//Text//Manuscripts//Data//YuPeixin//AusculPi//'

# %%
filename = 'Numpy_Array_File_2020-06-12_08_52_02.npy'

# %%
line = pathBase + filename

# %%
arr = np.load(line)

# %%
arr
# Out:
# array([[  358,   369,   365, ...,    92,    79,    65],
#        [   10,   -16,     9, ...,   283,   286,   304],
#        [  341,   369,   392, ...,   241,   217,   230],
#        ...,
#        [ 1151,  1154,  1178, ...,  8652,  8670,  8684],
#        [ 8654,  8676,  8642, ..., -2072, -2206, -2346],
#        [    3, -6568, -6578, ..., -6175, -6163, -6136]], dtype=int16)

# %%
arr.shape
# Out:
# (2583, 512)

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(arr[0], linewidth=1.0, color='black')

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(arr[:,100], linewidth=1.0, color='black')

# %%
start = 1377
end = 1910

start_adj = int(start * 2583 / 3000)
end_adj = int(end * 2583 / 3000)

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(arr[start_adj:end_adj,86], linewidth=1.0, color='black')

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(arr[start_adj:end_adj,70:500], linewidth=0.6, color='black')

# %%
fig.savefig('Phonocardiograph_YuPeixin.png', dpi=400)

# %%
s.show()
