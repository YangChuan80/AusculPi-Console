# %%
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#pathBase = 'E://Chuan//Documents//GitHub//AusculPi//Data//VSD//'
#pathBase = 'I://Chuan//Documents//GitHub//AusculPi//Data//VSD//'
#pathBase = 'C://Users//Chuan//OneDrive//Dowrun//Text//Manuscripts//Sound//TAVR_post//'

# %%
pathBase = 'C://Users//triti//OneDrive//Dowrun//Text//Manuscripts//Data//WangZhencai//AusculPi//'

# %%
filename = 'Numpy_Array_File_2020-06-19_10_36_04.npy'

# %%
line = pathBase + filename

# %%
arr = np.load(line)

# %%
arr
# Out:
# array([[   85,   -31,   -25, ...,   190,   157,   128],
#        [  128,    90,    79, ...,   422,   430,   477],
#        [  477,   453,   479, ...,  -114,  -136,  -123],
#        ...,
#        [ 8094,  8115,  8098, ...,  2966,  2973,  2962],
#        [ 2991,  2981,  2981, ..., -4152, -4200, -4205],
#        [-4233, -4241, -4290, ...,  -429,  -459,  -453]], dtype=int16)

# %%
arr.shape
# Out:
# (2583, 512)

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(arr[0])

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(arr[:,350])

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(arr[121:600,350])

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(arr[500:700,200])

# %%
s.show()
