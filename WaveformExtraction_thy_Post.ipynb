# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import math
import pingouin as pg
# %matplotlib inline

# %% [markdown]
# # Patient 8 THY

# %% [markdown]
# ## 3M Littmann Data

# %%
#image = Image.open('3M.bmp')
image = Image.open('3M_thy_post_s.bmp')
image
# Out:
# <PIL.BmpImagePlugin.BmpImageFile image mode=RGB size=314x600 at 0x17CD454E888>

# %%
x = image.size[0]
y = image.size[1]

# %%
print(x)
print(y)
# Out:
# 314
# 600

# %%
matrix = []
points = []
integrated_density = 0

for i in range(x):
    matrix.append([])
    for j in range(y):
        matrix[i].append(image.getpixel((i,j)))
        #integrated_density += image.getpixel((i,j))[1]
        #points.append(image.getpixel((i,j))[1])

# %% [markdown]
# ### Extract Red Line Position

# %%
redMax = 0
xStore = 0
yStore = 0
for xAxis in range(x):
    for yAxis in range(y):
        currentPoint = matrix[xAxis][yAxis]
        if currentPoint[0] == 255 and currentPoint[1] < 10 and currentPoint[2] < 10:
            redMax = currentPoint[0]
            xStore = xAxis
            yStore = yAxis
            
print(xStore, yStore)
# Out:
# 313 279

# %% [markdown]
# ### Extract Blue Points

# %%
redline_pos = 279
gain = 120
absMax = 0
littmannArr = []
points_vertical = []
theOne = 0

for xAxis in range(x):
    for yAxis in range(y):
        currentPoint = matrix[xAxis][yAxis]
        # Pickup Blue points
        if currentPoint[2] == 255 and currentPoint[0] < 220 and currentPoint[1] < 220:
            points_vertical.append(yAxis)
            
    #print(points_vertical)
    
    
    # Choose the largest amplitude
    for item in points_vertical:
        
        if abs(item-redline_pos) > absMax:
            absMax = abs(item-redline_pos)
            theOne = item 
    littmannArr.append((theOne-redline_pos)*gain)
    
    absMax = 0  
    theOne = 0
    points_vertical = []

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(littmannArr, linewidth=0.6, color='blue')

# %% [markdown]
# # Ascul Pi Data

# %%
pathBase = 'C://Users//triti//OneDrive//Dowrun//Text//Manuscripts//Data//TianHaoyang//AusculPi_Post//'
filename = 'Numpy_Array_File_2020-06-24_18_15_52.npy'
line = pathBase + filename
arr = np.load(line)
arr
# Out:
# array([[     0,    988,      3, ...,  -1058,   -543,   -103],
#        [   265,    449,    418, ...,   1044,    865,    656],
#        [   314,     44,   -108, ...,    822,    824,    780],
#        ...,
#        [-10644, -10735, -10798, ...,  20326,  20361,  20367],
#        [  1455,  -2636,  -2614, ...,  -5534,  -5520,  -5495],
#        [ -5507,  -5479,  -5435, ..., -10191, -10175, -10158]], dtype=int16)

# %%
arr.shape
# Out:
# (2583, 512)

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(arr[0], linewidth=1.0, color='black')

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(arr[:,100], linewidth=1.0, color='black')

# %%
start = 1675
end = 2040

start_adj = int(start * 2583 / 3000)
end_adj = int(end * 2583 / 3000)

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(arr[start_adj:end_adj,240], linewidth=0.6, color='black')

# %%
start_adj-end_adj
# Out:
# -314

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(littmannArr, linewidth=0.6, color='blue')

# %%
asculArr = arr[start_adj:end_adj,400]

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(asculArr, linewidth=0.6, color='black')

# %% [markdown]
# ## Preprocess the two array

# %%
asculArr_processed = []
littmannArr_processed = []

for ascul in asculArr:
    asculArr_processed.append(math.fabs(ascul))
    
for item in littmannArr:
    littmannArr_processed.append(math.fabs(item))

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(asculArr_processed, linewidth=0.6, color='black')

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(littmannArr_processed, linewidth=0.6, color='blue')

# %%
len(littmannArr)
# Out:
# 314

# %%
len(asculArr)
# Out:
# 314

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(asculArr_processed[:170], linewidth=0.6, color='black')

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(littmannArr_processed[:170], linewidth=0.6, color='blue')

# %% [markdown]
# ### Coeffient

# %%
stats.pearsonr(asculArr_processed, littmannArr_processed)
# Out:
# (0.3090226129074174, 2.2511180570343173e-08)

# %%
stats.pearsonr(asculArr_processed[:170], littmannArr_processed[:170])
# Out:
# (0.5137916562514859, 7.755897526025553e-13)

# %% [markdown]
# ### Fitness

# %%
stats.chisquare(asculArr_processed[:80], littmannArr_processed[2:82])
# Out:
# Power_divergenceResult(statistic=1055280.295353781, pvalue=0.0)

# %%
def cosCalculate(a, b):
    l = len(a)
    
    sumXY = 0
    sumRootXSquare = 0
    sumRootYSquare = 0
    
    for i in range(l):
        sumXY = sumXY + a[i]*b[i]
        sumRootXSquare = sumRootXSquare + math.sqrt(a[i]**2)
        sumRootYSquare = sumRootYSquare + math.sqrt(b[i]**2)
        
    cosValue = sumXY / (sumRootXSquare * sumRootYSquare)
    
    return cosValue

# %%
cosCalculate(asculArr_processed, littmannArr_processed)
# Out:
# 0.00407564492409666

# %% [markdown]
# # Cross Comparing

# %% [markdown]
# ### Volunteer 3M vs Patient 8 Ascul Post

# %%
#image = Image.open('3M.bmp')
image = Image.open('3Ms.bmp')
image
# Out:
# <PIL.BmpImagePlugin.BmpImageFile image mode=RGB size=448x99 at 0x17CD8C7B148>

# %%
x = image.size[0]
y = image.size[1]

# %%
matrix = []
points = []
integrated_density = 0

for i in range(x):
    matrix.append([])
    for j in range(y):
        matrix[i].append(image.getpixel((i,j)))
        #integrated_density += image.getpixel((i,j))[1]
        #points.append(image.getpixel((i,j))[1])

# %%
redline_pos = 51
absMax = 0
littmannArr2 = []
points_vertical = []
theOne = 0

for xAxis in range(x):
    for yAxis in range(y):
        currentPoint = matrix[xAxis][yAxis]
        # Pickup Blue points
        if currentPoint[2] == 255 and currentPoint[0] < 220 and currentPoint[1] < 220:
            points_vertical.append(yAxis)
            
    #print(points_vertical)
    
    
    # Choose the largest amplitude
    for item in points_vertical:
        
        if abs(item-redline_pos) > absMax:
            absMax = abs(item-redline_pos)
            theOne = item 
    littmannArr2.append((theOne-redline_pos)*800)
    
    absMax = 0  
    theOne = 0
    points_vertical = []

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(littmannArr2, linewidth=0.6, color='blue')

# %%
len(littmannArr2)
# Out:
# 448

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(littmannArr2[:400], linewidth=0.6, color='blue')

# %%
asculArr
# Out:
# array([ -9380,     70,   3697,   1088,  -3572,  27300, -20465, -28731,
#         23419, -21217,   7902,    580,   8645,   1123,   4195,  -2905,
#         -6090,   4512,   4511,  -3313,   5206,  -6673,  30921, -14026,
#         24599,    -88,  -2786,  -7992,    120,   2092,  -2337,   3560,
#          2280,   4540,  -1402,  -1221,     40,   6175,  -1302,  25809,
#        -11990, -24806,  32541, -10712,  14891, -17723,    442,  -2496,
#          2897,   2285,   4518,   5342,  -1979,  -2752,  -6632,  -5537,
#         28544, -22971,  32261,  -1445,  -4576,  -4784,   9799,   6422,
#          7757,   9230,  -3360,   -220,  -2219,    851,  11500,   4503,
#         -4270,  26055,  -2739, -30946,  31608, -20966,   8921,   2089,
#          3578,    193,   3504,    991,   1022,  -3229,   3680,   4855,
#          3454,  -4483,  -6359,  11108,  22185,   9245,  -1839,   -555,
#          -359,   8404,   5664,   2395,  -7319,   5697,   8700,  -4889,
#         -1548,   2913,   1592,  -4198,  11696, -14070,  19852,  15443,
#           463,  11944,  -1254,   3133,   8008,   3743,   1444,     39,
#           648,  -6943,   8059,   4654,  -6913,  13054, -15166,   2575,
#          -397,  -6575,  -7734,  -2301,   6529,   2526,  -3159,  -2637,
#          6870,   7369,  -9159,   4801,   4361,  -5039,  17100,   9014,
#         -3066,  20399, -16266,  -3535,   2954,    946,  -3103,    447,
#          -580,   2445,   7020,   -901,   2358,  -4502,  -6440,  -2306,
#         20784,  -1730,  11030,  -2508,  -2763,  -1665,   2376,    286,
#          9105,  -2896,    625,   8536,  -2280,    762,   8727, -14008,
#           934,  23260,   1766, -27081,  29628, -30821,   4389,   2055,
#         -5226,   9446,  18713,  11709, -13093, -10080,   2004,   2449,
#          3434,  10997,   6682, -23086,  -4778,  -4841,   -695,  -1927,
#          5575,  12606,  -5846,  -1101,  -3810,  -1624,   -441,   5950,
#          5780,    877, -11043,  26444, -10177,   2108,  11065,  -9861,
#         -7114,  -5818,   2038,   4282,   7562,  -1336,  12222,   2795,
#         -4019,   3162,  -7375, -14894,  23699, -28349,  11194,   3163,
#         -6995,  -5251,  -2898,   3004,  -2518,  -2819,    954,   -384,
#         -1790,  -4562,  -1134,  -2261,  -8137,  26047,  -5034, -30815,
#         32767,    -51, -11826, -13761, -12254,  -1090,   4562,   9869,
#         -2843,  -3247,  -1248,  -8830,    486,  -2496,     72, -32768,
#         -8102,  13851,  -9172,  -1385,  -2829,   8374,  -1970,  -2096,
#         -4097,   3168,   3178,   3615,   2286,   1002,  -8344,  -2028,
#         21899, -17953, -19218,   1702, -15104,   1341,  -4236,  -4134,
#         -7238,   6866,    611,    465,   6266,   -200,  -4766, -11022,
#         -5846,  -6790,  -7181,  10050,  -5001, -16241, -16348,   3564,
#          4487,   -366,  -3621,  -2437,   3683,  -2249,   -929,  -5164,
#         -2364,  -3454], dtype=int16)

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(asculArr, linewidth=0.6, color='black')

# %%
asculArr_processed = []
littmannArr2_processed = []

for ascul in asculArr:
    asculArr_processed.append(math.fabs(ascul))
    
for item in littmannArr2[:400]:
    littmannArr2_processed.append(math.fabs(item))

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(asculArr_processed, linewidth=1.0, color='black')

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(littmannArr2_processed[:314], linewidth=1.0, color='blue')

# %%
len(asculArr_processed)
# Out:
# 314

# %%
len(littmannArr2_processed[:314])
# Out:
# 314

# %%
stats.pearsonr(asculArr_processed, littmannArr2_processed[:314])
# Out:
# (0.047209518096309536, 0.4044594251160515)
