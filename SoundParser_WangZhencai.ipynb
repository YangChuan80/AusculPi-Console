# %%
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#pathBase = 'E://Chuan//Documents//GitHub//AusculPi//Data//VSD//'
#pathBase = 'I://Chuan//Documents//GitHub//AusculPi//Data//VSD//'
#pathBase = 'C://Users//Chuan//OneDrive//Dowrun//Text//Manuscripts//Sound//TAVR_post//'

# %%
#pathBase = 'C://Users//Chuan//OneDrive//Dowrun//Text//Manuscripts//Data//ZhangGuohao//AusculPi//'
pathBase = 'C://Users//triti//OneDrive//Dowrun//Text//Manuscripts//Data//WangZhencai//AusculPi//'

# %%
filename = 'Numpy_Array_File_2020-06-19_10_37_30.npy'

# %%
line = pathBase + filename

# %%
arr = np.load(line)

# %%
arr
# Out:
# array([[   149,    141,    121, ...,    527,    534,    550],
#        [   554,    585,    565, ...,    106,     99,     96],
#        [   124,    114,    136, ...,    218,    215,    221],
#        ...,
#        [  3692,   3681,   3618, ..., -14527, -14571, -14658],
#        [     0,  15645,  15757, ...,   7233,   7302,   7358],
#        [  7435,   7518,   7625, ...,    426,    351,    235]], dtype=int16)

# %%
arr.shape
# Out:
# (2583, 512)

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(arr[0], linewidth=1.0, color='black')

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(arr[:,100], linewidth=1.0, color='black')

# %%
start = 1200
end = 2200

start_adj = int(start * 2583 / 3000)
end_adj = int(end * 2583 / 3000)

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(arr[start_adj:end_adj, 480], linewidth=0.5, color='black')

# %%
fig.savefig('Phonocardiograph_WangZhencai.png', dpi=400)

# %%
s.show()
