# %%
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#pathBase = 'E://Chuan//Documents//GitHub//AusculPi//Data//VSD//'
#pathBase = 'I://Chuan//Documents//GitHub//AusculPi//Data//VSD//'
#pathBase = 'C://Users//Chuan//OneDrive//Dowrun//Text//Manuscripts//Sound//TAVR_post//'

# %%
pathBase = 'C://Users//triti//OneDrive//Dowrun//Text//Manuscripts//Data//TianHaoyang//AusculPi//'

# %%
filename = 'Numpy_Array_File_2020-06-18_11_02_04.npy'

# %%
line = pathBase + filename

# %%
arr = np.load(line)

# %%
arr
# Out:
# array([[   411,    397,    397, ...,    276,    265,    267],
#        [   305,    289,    315, ...,    225,    252,    283],
#        [   341,    333,    350, ...,    337,    365,    371],
#        ...,
#        [  -468,   -496,   -491, ...,  15989,  16102,  16244],
#        [ 16400,  16538,  16658, ..., -32768, -32768, -32768],
#        [-32768, -32768, -32768, ...,  18317,  18451,  18571]], dtype=int16)

# %%
arr.shape
# Out:
# (2583, 512)

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(arr[0])

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(arr[:,200])

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(arr[1000:1400,420])

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(arr[1000:1400,280])

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(arr[500:700,200])

# %%
s.show()
