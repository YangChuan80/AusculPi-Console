# %%
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#pathBase = 'E://Chuan//Documents//GitHub//AusculPi//Data//VSD//'
#pathBase = 'I://Chuan//Documents//GitHub//AusculPi//Data//VSD//'
#pathBase = 'C://Users//Chuan//OneDrive//Dowrun//Text//Manuscripts//Sound//TAVR_post//'

# %%
pathBase = 'C://Users//Chuan//OneDrive//Dowrun//Text//Manuscripts//Data//TianHaoyang//AusculPi//'

# %%
filename = 'Numpy_Array_File_2020-07-02_13_57_25.npy'

# %%
line = pathBase + filename

# %%
arr = np.load(line)

# %%
arr
# Out:
# array([[   411,    397,    397, ...,    276,    265,    267],
#        [   305,    289,    315, ...,    225,    252,    283],
#        [   341,    333,    350, ...,    337,    365,    371],
#        ...,
#        [  -468,   -496,   -491, ...,  15989,  16102,  16244],
#        [ 16400,  16538,  16658, ..., -32768, -32768, -32768],
#        [-32768, -32768, -32768, ...,  18317,  18451,  18571]], dtype=int16)

# %%
arr.shape
# Out:
# (2583, 512)

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(arr[0])

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(arr[:,200], linewidth=1.0, color='black')

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(arr[1002:1405, 100], linewidth=1.0, color='black')

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(arr[1002:1290, 200:500], linewidth=1.0, color='black')

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(arr[1002:1290, 100:400], linewidth=0.3, color='black')

# %%
fig.savefig('Phonocardiograph_Tian.png', dpi=400)
