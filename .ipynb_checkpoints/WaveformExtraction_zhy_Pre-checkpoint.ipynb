# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import math
# %matplotlib inline

# %% [markdown]
# # Patient 8 THY

# %% [markdown]
# ## 3M Littmann Data

# %%
#image = Image.open('3M.bmp')
image = Image.open('3M_zhy_Pre.bmp')
image
# Out:
# <PIL.BmpImagePlugin.BmpImageFile image mode=RGB size=799x140 at 0x1B721228F48>

# %%
x = image.size[0]
y = image.size[1]

# %%
print(x)
print(y)
# Out:
# 799
# 140

# %%
matrix = []
points = []
integrated_density = 0

for i in range(x):
    matrix.append([])
    for j in range(y):
        matrix[i].append(image.getpixel((i,j)))
        #integrated_density += image.getpixel((i,j))[1]
        #points.append(image.getpixel((i,j))[1])

# %% [markdown]
# ### Extract Red Line Position

# %%
redMax = 0
xStore = 0
yStore = 0
for xAxis in range(x):
    for yAxis in range(y):
        currentPoint = matrix[xAxis][yAxis]
        if currentPoint[0] == 255 and currentPoint[1] < 10 and currentPoint[2] < 10:
            redMax = currentPoint[0]
            xStore = xAxis
            yStore = yAxis
            
print(xStore, yStore)
# Out:
# 798 62

# %% [markdown]
# ### Extract Blue Points

# %%
redline_pos = 62
gain = 120
absMax = 0
littmannArr = []
points_vertical = []
theOne = 0

for xAxis in range(x):
    for yAxis in range(y):
        currentPoint = matrix[xAxis][yAxis]
        # Pickup Blue points
        if currentPoint[2] == 255 and currentPoint[0] < 100 and currentPoint[1] < 100:
            points_vertical.append(yAxis)
            
    #print(points_vertical)
    
    
    # Choose the largest amplitude
    for item in points_vertical:
        
        if abs(item-redline_pos) > absMax:
            absMax = abs(item-redline_pos)
            theOne = item 
    littmannArr.append((theOne-redline_pos)*gain)
    
    absMax = 0  
    theOne = 0
    points_vertical = []

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(littmannArr, linewidth=0.6, color='blue')

# %% [markdown]
# # Ascul Pi Data

# %%
pathBase = 'C://Users//triti//OneDrive//Dowrun//Text//Manuscripts//Data//ZhaoHongye//AusculPi//'
filename = 'Numpy_Array_File_2020-07-02_13_57_25.npy'
line = pathBase + filename
arr = np.load(line)
arr
# Out:
# array([[  252,   258,   301, ...,   324,   279,   191],
#        [  122,    32,   -26, ...,   243,   244,   249],
#        [  229,   178,   113, ...,    69,   139,    90],
#        ...,
#        [-1153, -1168, -1151, ...,  6113,  6004,  5883],
#        [ 5742,  5612,  5534, ..., 32767, 32767, 32767],
#        [    3,  2268,  2242, ..., -1439, -1450, -1463]], dtype=int16)

# %%
arr.shape
# Out:
# (2583, 512)

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(arr[0], linewidth=1.0, color='black')

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(arr[:,200], linewidth=1.0, color='black')

# %%
start = 472
end = 1400

start_adj = int(start * 2583 / 3000)
end_adj = int(end * 2583 / 3000)

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(arr[start_adj:end_adj,300], linewidth=0.6, color='black')

# %%
start_adj-end_adj
# Out:
# -799

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(littmannArr, linewidth=0.6, color='blue')

# %%
asculArr = arr[start_adj:end_adj,300]

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(asculArr, linewidth=0.6, color='black')

# %% [markdown]
# ## Preprocess the two array

# %%
asculArr_processed = []
littmannArr_processed = []

for ascul in asculArr:
    asculArr_processed.append(math.fabs(ascul))
    
for item in littmannArr:
    littmannArr_processed.append(math.fabs(item))

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(asculArr_processed, linewidth=1.0, color='black')

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(littmannArr_processed, linewidth=1.0, color='blue')

# %%
len(littmannArr)
# Out:
# 799

# %%
len(asculArr)
# Out:
# 799

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(asculArr_processed[:100], linewidth=1.0, color='black')

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(littmannArr_processed[:100], linewidth=1.0, color='blue')

# %% [markdown]
# ### Coeffient

# %%
stats.pearsonr(asculArr_processed, littmannArr_processed)
# Out:
# (0.03497698767612229, 0.32342973471301684)

# %%
stats.pearsonr(asculArr_processed[:100], littmannArr_processed[:100])
# Out:
# (-0.009141186470161839, 0.9280770577730177)

# %% [markdown]
# ### Fitness

# %%
stats.chisquare(asculArr_processed[:80], littmannArr_processed[2:82])
# Out:
# Power_divergenceResult(statistic=722028.114779749, pvalue=0.0)

# %%
def cosCalculate(a, b):
    l = len(a)
    
    sumXY = 0
    sumRootXSquare = 0
    sumRootYSquare = 0
    
    for i in range(l):
        sumXY = sumXY + a[i]*b[i]
        sumRootXSquare = sumRootXSquare + math.sqrt(a[i]**2)
        sumRootYSquare = sumRootYSquare + math.sqrt(b[i]**2)
        
    cosValue = sumXY / (sumRootXSquare * sumRootYSquare)
    
    return cosValue

# %%
cosCalculate(asculArr_processed, littmannArr_processed)
# Out:
# 0.006115652405443805
