# %%
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pathBase = 'E://Chuan//Documents//GitHub//AusculPi//Data//VSD//'

# %%
filename = 'Array_File_2020-05-27_16_54_42.np.npy'

# %%
line = pathBase + filename

# %%
arr = np.load(line)

# %%
arr
# Out:
# array([[  5823,   5974,   6158, ...,  24394,  24308,  24239],
#        [ 24175,  24102,  24015, ...,   8483,   8292,   8136],
#        [  7998,   7868,   7737, ...,  23866,  24055,  24226],
#        ...,
#        [ -5882,  -6103,  -6357, ..., -13594, -13382, -13126],
#        [-12881, -12631, -12388, ...,   3395,   3555,   3700],
#        [  3857,   4036,   4185, ...,  -5434,  -5385,  -5295]], dtype=int16)

# %%
arr.shape
# Out:
# (2583, 512)

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(arr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-9424118aae3d> in <module>
#       2 s = fig.add_subplot(111)
#       3 s.plot(arr)
# ----> 4 fig.savefig(png_output_filename, dpi=200)
#
# NameError: name 'png_output_filename' is not defined
