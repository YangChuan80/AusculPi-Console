# %%
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#pathBase = 'E://Chuan//Documents//GitHub//AusculPi//Data//VSD//'
#pathBase = 'I://Chuan//Documents//GitHub//AusculPi//Data//VSD//'
pathBase = 'C://Users//Chuan//OneDrive//Dowrun//Text//Manuscripts//Sound//TAVR_post//'

# %%
filename = 'Numpy_Array_File_2020-06-05_16_12_44.npy'

# %%
line = pathBase + filename

# %%
arr = np.load(line)

# %%
arr
# Out:
# array([[  556,   540,   541, ...,   352,   396,   374],
#        [  373,   357,   371, ...,   109,   124,    62],
#        [   13,     7,   -18, ...,   146,   180,   222],
#        ...,
#        [ 3190,  3231,  3287, ...,  1937,  1915,  1877],
#        [30057, -2712, -2748, ..., -1840, -1842, -1860],
#        [-1842, -1900, -1900, ..., -2800, -2759, -2711]], dtype=int16)

# %%
arr.shape
# Out:
# (2583, 512)

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(arr[0])

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(arr[:,200])

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(arr[1500:2200,300])

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(arr[500:700,200])

# %%
s.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-daffe8404596> in <module>
# ----> 1 s.show()
#
# AttributeError: 'AxesSubplot' object has no attribute 'show'
