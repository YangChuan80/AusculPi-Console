# %%
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#pathBase = 'E://Chuan//Documents//GitHub//AusculPi//Data//VSD//'
#pathBase = 'I://Chuan//Documents//GitHub//AusculPi//Data//VSD//'
#pathBase = 'C://Users//Chuan//OneDrive//Dowrun//Text//Manuscripts//Sound//TAVR_post//'

# %%
pathBase = 'C://Users//triti//OneDrive//Dowrun//Text//Manuscripts//Data//HouCuiyu//AusculPi//'

# %%
filename = 'Numpy_Array_File_2020-06-16_13_59_31.npy'

# %%
line = pathBase + filename

# %%
arr = np.load(line)

# %%
arr
# Out:
# array([[  438,   459,   437, ...,   425,   412,   411],
#        [  435,   432,   415, ...,   532,   510,   540],
#        [  532,   559,   584, ...,    10,     8,    38],
#        ...,
#        [ 4142,  4271,  4353, ...,  7086,  7029,  6994],
#        [ 6959,  6916,  6846, ...,  1842,  1801,  1844],
#        [29779, -3055, -3141, ...,  2262,  2258,  2238]], dtype=int16)

# %%
arr.shape
# Out:
# (2583, 512)

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(arr[0])

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(arr[:,300])

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(arr[0:10000,450])

# %%
fig = plt.figure()
s = fig.add_subplot(111)
s.plot(arr[500:700,200])

# %%
s.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-daffe8404596> in <module>
# ----> 1 s.show()
#
# AttributeError: 'AxesSubplot' object has no attribute 'show'
